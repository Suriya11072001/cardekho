# %%
import pandas as pd
bangalore_data=pd.read_excel('C:\\Users\\HP\\Desktop\\capstone.3\\bangalore_cars.xlsx')
bangalore_data
import ast
import numpy as np

# %%
print(bangalore_data.columns)
# Out:
# Index(['new_car_detail', 'new_car_overview', 'new_car_feature',
#        'new_car_specs', 'car_links'],
#       dtype='object')

# %%
fuel_type = []
Kilometers_driven = []
Transmission_type = []
No_of_owners = []
Original_Equipment_Manufacturer = []
model = []
model_Year = []
Price = []
registration_year = []
seats = []
engine_cc = []
Mileage = []

for i in range(bangalore_data.shape[0]):
    new_car_detail = bangalore_data['new_car_detail'][i]
    new_car_overview = bangalore_data['new_car_overview'][i]
    new_car_specs = bangalore_data['new_car_specs'][i]
    
    data_dict = ast.literal_eval(new_car_detail)
    data_dict_1 = ast.literal_eval(new_car_overview)
    data_dict_2 = ast.literal_eval(new_car_specs)
    
    fuel_type.append(data_dict['ft'])
    Kilometers_driven.append(data_dict['km'])
    Transmission_type.append(data_dict['transmission'])
    No_of_owners.append(data_dict['ownerNo'])
    Original_Equipment_Manufacturer.append(data_dict['oem'])
    model.append(data_dict['model'])
    model_Year.append(int(data_dict['modelYear']))
    Price.append(data_dict['price'])
    registration_year.append(data_dict_1['top'][0]['value'][-4:])
    seats.append(data_dict_1['top'][3]['value'][0])
    
    try:
        if (data_dict_2['data'][0]['list'][2]['value']).isnumeric():
            engine_cc.append(data_dict_2['data'][0]['list'][2]['value'])
        else:
            engine_cc.append(data_dict_2['data'][0]['list'][1]['value'])
    except:
        engine_cc.append(np.nan)
        
    Mileage.append(data_dict_2['top'][0]['value'][:-5])

        
    
bangalore_data['Fuel_Type'] = fuel_type
bangalore_data['Kilometers_Driven'] = Kilometers_driven
bangalore_data['Transmission_Type'] = Transmission_type
bangalore_data['No_of_Owners'] = No_of_owners
bangalore_data['Manufactured_By'] = Original_Equipment_Manufacturer
bangalore_data['Car_Model'] = model
bangalore_data['Car_Produced_Year'] = model_Year
bangalore_data['Car_Price'] = Price
bangalore_data['Registration_Year'] = registration_year
bangalore_data['No_of_Seats'] = seats
bangalore_data['Engine_CC'] = engine_cc
bangalore_data['Mileage(kmpl)'] = Mileage

# %%
bangalore_data
# Out:
#                                          new_car_detail  \
# 0     {'it': 0, 'ft': 'Petrol', 'bt': 'Hatchback', '...
# 1     {'it': 0, 'ft': 'Petrol', 'bt': 'SUV', 'km': '...
# 2     {'it': 0, 'ft': 'Petrol', 'bt': 'Hatchback', '...
# 3     {'it': 0, 'ft': 'Petrol', 'bt': 'Sedan', 'km':...
# 4     {'it': 0, 'ft': 'Diesel', 'bt': 'SUV', 'km': '...
# ...                                                 ...
# 1476  {'it': 0, 'ft': 'Diesel', 'bt': 'SUV', 'km': '...
# 1477  {'it': 0, 'ft': 'Petrol', 'bt': 'Sedan', 'km':...
# 1478  {'it': 0, 'ft': 'Petrol', 'bt': 'Hatchback', '...
# 1479  {'it': 0, 'ft': 'Diesel', 'bt': 'Hatchback', '...
# 1480  {'it': 0, 'ft': 'Petrol', 'bt': 'Hatchback', '...
#
#                                        new_car_overview  \
# 0     {'heading': 'Car overview', 'top': [{'key': 'R...
# 1     {'heading': 'Car overview', 'top': [{'key': 'R...
# 2     {'heading': 'Car overview', 'top': [{'key': 'R...
# 3     {'heading': 'Car overview', 'top': [{'key': 'R...
# ...

# %%
bangalore_data['Location']='Bangalore'

# %%
chennai_data=pd.read_excel('C:\\Users\\HP\\Desktop\\capstone.3\\chennai_cars.xlsx')
fuel_type = []
Kilometers_driven = []
Transmission_type = []
No_of_owners = []
Original_Equipment_Manufacturer = []
model = []
model_Year = []
Price = []
registration_year = []
seats = []
engine_cc = []
Mileage = []

for i in range(chennai_data.shape[0]):
    new_car_detail = chennai_data['new_car_detail'][i]
    new_car_overview = chennai_data['new_car_overview'][i]
    new_car_specs = chennai_data['new_car_specs'][i]
    
    data_dict = ast.literal_eval(new_car_detail)
    data_dict_1 = ast.literal_eval(new_car_overview)
    data_dict_2 = ast.literal_eval(new_car_specs)
    
    fuel_type.append(data_dict['ft'])
    Kilometers_driven.append(data_dict['km'])
    Transmission_type.append(data_dict['transmission'])
    No_of_owners.append(data_dict['ownerNo'])
    Original_Equipment_Manufacturer.append(data_dict['oem'])
    model.append(data_dict['model'])
    model_Year.append(int(data_dict['modelYear']))
    Price.append(data_dict['price'])
    registration_year.append(data_dict_1['top'][0]['value'][-4:])
    seats.append(data_dict_1['top'][3]['value'][0])
    
    try:
        if (data_dict_2['data'][0]['list'][2]['value']).isnumeric():
            engine_cc.append(data_dict_2['data'][0]['list'][2]['value'])
        else:
            engine_cc.append(data_dict_2['data'][0]['list'][1]['value'])
    except:
        engine_cc.append(np.nan)
        
    Mileage.append(data_dict_2['top'][0]['value'][:-5])

        
    
chennai_data['Fuel_Type'] = fuel_type
chennai_data['Kilometers_Driven'] = Kilometers_driven
chennai_data['Transmission_Type'] = Transmission_type
chennai_data['No_of_Owners'] = No_of_owners
chennai_data['Manufactured_By'] = Original_Equipment_Manufacturer
chennai_data['Car_Model'] = model
chennai_data['Car_Produced_Year'] = model_Year
chennai_data['Car_Price'] = Price
chennai_data['Registration_Year'] = registration_year
chennai_data['No_of_Seats'] = seats
chennai_data['Engine_CC'] = engine_cc
chennai_data['Mileage(kmpl)'] = Mileage

# %%
chennai_data
# Out:
#                                          new_car_detail  \
# 0     {'it': 0, 'ft': 'Petrol', 'bt': 'SUV', 'km': '...
# 1     {'it': 0, 'ft': 'Petrol', 'bt': 'Minivans', 'k...
# 2     {'it': 0, 'ft': 'Petrol', 'bt': 'SUV', 'km': '...
# 3     {'it': 0, 'ft': 'Petrol', 'bt': 'Hatchback', '...
# 4     {'it': 0, 'ft': 'Petrol', 'bt': 'Hatchback', '...
# ...                                                 ...
# 1414  {'it': 0, 'ft': 'Petrol', 'bt': 'Hatchback', '...
# 1415  {'it': 0, 'ft': 'Diesel', 'bt': 'SUV', 'km': '...
# 1416  {'it': 0, 'ft': 'Petrol', 'bt': 'SUV', 'km': '...
# 1417  {'it': 0, 'ft': 'Diesel', 'bt': 'SUV', 'km': '...
# 1418  {'it': 0, 'ft': 'Diesel', 'bt': 'Sedan', 'km':...
#
#                                        new_car_overview  \
# 0     {'heading': 'Car overview', 'top': [{'key': 'R...
# 1     {'heading': 'Car overview', 'top': [{'key': 'R...
# 2     {'heading': 'Car overview', 'top': [{'key': 'R...
# 3     {'heading': 'Car overview', 'top': [{'key': 'R...
# ...

# %%
chennai_data['Location']='Chennai'

# %%
delhi_data=pd.read_excel('C:\\Users\\HP\\Desktop\\capstone.3\\delhi_cars.xlsx')
fuel_type = []
Kilometers_driven = []
Transmission_type = []
No_of_owners = []
Original_Equipment_Manufacturer = []
model = []
model_Year = []
Price = []
registration_year = []
seats = []
engine_cc = []
Mileage = []

for i in range(delhi_data.shape[0]):
    new_car_detail = delhi_data['new_car_detail'][i]
    new_car_overview = delhi_data['new_car_overview'][i]
    new_car_specs = delhi_data['new_car_specs'][i]
    
    data_dict = ast.literal_eval(new_car_detail)
    data_dict_1 = ast.literal_eval(new_car_overview)
    data_dict_2 = ast.literal_eval(new_car_specs)
    
    fuel_type.append(data_dict['ft'])
    Kilometers_driven.append(data_dict['km'])
    Transmission_type.append(data_dict['transmission'])
    No_of_owners.append(data_dict['ownerNo'])
    Original_Equipment_Manufacturer.append(data_dict['oem'])
    model.append(data_dict['model'])
    model_Year.append(int(data_dict['modelYear']))
    Price.append(data_dict['price'])
    registration_year.append(data_dict_1['top'][0]['value'][-4:])
    seats.append(data_dict_1['top'][3]['value'][0])
    
    try:
        if (data_dict_2['data'][0]['list'][2]['value']).isnumeric():
            engine_cc.append(data_dict_2['data'][0]['list'][2]['value'])
        else:
            engine_cc.append(data_dict_2['data'][0]['list'][1]['value'])
    except:
        engine_cc.append(np.nan)
        
    Mileage.append(data_dict_2['top'][0]['value'][:-5])

        
    
delhi_data['Fuel_Type'] = fuel_type
delhi_data['Kilometers_Driven'] = Kilometers_driven
delhi_data['Transmission_Type'] = Transmission_type
delhi_data['No_of_Owners'] = No_of_owners
delhi_data['Manufactured_By'] = Original_Equipment_Manufacturer
delhi_data['Car_Model'] = model
delhi_data['Car_Produced_Year'] = model_Year
delhi_data['Car_Price'] = Price
delhi_data['Registration_Year'] = registration_year
delhi_data['No_of_Seats'] = seats
delhi_data['Engine_CC'] = engine_cc
delhi_data['Mileage(kmpl)'] = Mileage

# %%
delhi_data
# Out:
#                                          new_car_detail  \
# 0     {'it': 0, 'ft': 'Diesel', 'bt': 'SUV', 'km': '...
# 1     {'it': 0, 'ft': 'Petrol', 'bt': 'SUV', 'km': '...
# 2     {'it': 0, 'ft': 'Petrol', 'bt': 'SUV', 'km': '...
# 3     {'it': 0, 'ft': 'Petrol', 'bt': 'Hatchback', '...
# 4     {'it': 0, 'ft': 'Petrol', 'bt': 'SUV', 'km': '...
# ...                                                 ...
# 1480  {'it': 0, 'ft': 'Petrol', 'bt': 'Sedan', 'km':...
# 1481  {'it': 0, 'ft': 'Petrol', 'bt': 'SUV', 'km': '...
# 1482  {'it': 0, 'ft': 'Petrol', 'bt': 'Sedan', 'km':...
# 1483  {'it': 0, 'ft': 'Diesel', 'bt': 'SUV', 'km': '...
# 1484  {'it': 0, 'ft': 'Diesel', 'bt': 'SUV', 'km': '...
#
#                                        new_car_overview  \
# 0     {'heading': 'Car overview', 'top': [{'key': 'R...
# 1     {'heading': 'Car overview', 'top': [{'key': 'R...
# 2     {'heading': 'Car overview', 'top': [{'key': 'R...
# 3     {'heading': 'Car overview', 'top': [{'key': 'R...
# ...

# %%
delhi_data['Location']='Delhi'

# %%
hyderabad_data=pd.read_excel('C:\\Users\\HP\\Desktop\\capstone.3\\hyderabad_cars.xlsx')
fuel_type = []
Kilometers_driven = []
Transmission_type = []
No_of_owners = []
Original_Equipment_Manufacturer = []
model = []
model_Year = []
Price = []
registration_year = []
seats = []
engine_cc = []
Mileage = []

for i in range(hyderabad_data.shape[0]):
    new_car_detail = hyderabad_data['new_car_detail'][i]
    new_car_overview = hyderabad_data['new_car_overview'][i]
    new_car_specs = hyderabad_data['new_car_specs'][i]
    
    data_dict = ast.literal_eval(new_car_detail)
    data_dict_1 = ast.literal_eval(new_car_overview)
    data_dict_2 = ast.literal_eval(new_car_specs)
    
    fuel_type.append(data_dict['ft'])
    Kilometers_driven.append(data_dict['km'])
    Transmission_type.append(data_dict['transmission'])
    No_of_owners.append(data_dict['ownerNo'])
    Original_Equipment_Manufacturer.append(data_dict['oem'])
    model.append(data_dict['model'])
    model_Year.append(int(data_dict['modelYear']))
    Price.append(data_dict['price'])
    registration_year.append(data_dict_1['top'][0]['value'][-4:])
    seats.append(data_dict_1['top'][3]['value'][0])
    
    try:
        if (data_dict_2['data'][0]['list'][2]['value']).isnumeric():
            engine_cc.append(data_dict_2['data'][0]['list'][2]['value'])
        else:
            engine_cc.append(data_dict_2['data'][0]['list'][1]['value'])
    except:
        engine_cc.append(np.nan)
        
    Mileage.append(data_dict_2['top'][0]['value'][:-5])

        
    
hyderabad_data['Fuel_Type'] = fuel_type
hyderabad_data['Kilometers_Driven'] = Kilometers_driven
hyderabad_data['Transmission_Type'] = Transmission_type
hyderabad_data['No_of_Owners'] = No_of_owners
hyderabad_data['Manufactured_By'] = Original_Equipment_Manufacturer
hyderabad_data['Car_Model'] = model
hyderabad_data['Car_Produced_Year'] = model_Year
hyderabad_data['Car_Price'] = Price
hyderabad_data['Registration_Year'] = registration_year
hyderabad_data['No_of_Seats'] = seats
hyderabad_data['Engine_CC'] = engine_cc
hyderabad_data['Mileage(kmpl)'] = Mileage

# %%
hyderabad_data
# Out:
#                                          new_car_detail  \
# 0     {'it': 0, 'ft': 'Petrol', 'bt': 'Hatchback', '...
# 1     {'it': 0, 'ft': 'Petrol', 'bt': 'Hatchback', '...
# 2     {'it': 0, 'ft': 'Petrol', 'bt': 'SUV', 'km': '...
# 3     {'it': 0, 'ft': 'Petrol', 'bt': 'Hatchback', '...
# 4     {'it': 0, 'ft': 'Petrol', 'bt': 'SUV', 'km': '...
# ...                                                 ...
# 1478  {'it': 0, 'ft': 'Diesel', 'bt': 'SUV', 'km': '...
# 1479  {'it': 0, 'ft': 'Diesel', 'bt': 'Sedan', 'km':...
# 1480  {'it': 0, 'ft': 'Diesel', 'bt': 'Sedan', 'km':...
# 1481  {'it': 0, 'ft': 'Diesel', 'bt': 'SUV', 'km': '...
# 1482  {'it': 0, 'ft': 'Diesel', 'bt': 'MUV', 'km': '...
#
#                                        new_car_overview  \
# 0     {'heading': 'Car overview', 'top': [{'key': 'R...
# 1     {'heading': 'Car overview', 'top': [{'key': 'R...
# 2     {'heading': 'Car overview', 'top': [{'key': 'R...
# 3     {'heading': 'Car overview', 'top': [{'key': 'R...
# ...

# %%
hyderabad_data['Location']='Hyderabad'

# %%
jaipur_data=pd.read_excel('C:\\Users\\HP\\Desktop\\capstone.3\\jaipur_cars.xlsx')
fuel_type = []
Kilometers_driven = []
Transmission_type = []
No_of_owners = []
Original_Equipment_Manufacturer = []
model = []
model_Year = []
Price = []
registration_year = []
seats = []
engine_cc = []
Mileage = []

for i in range(jaipur_data.shape[0]):
    new_car_detail = jaipur_data['new_car_detail'][i]
    new_car_overview = jaipur_data['new_car_overview'][i]
    new_car_specs = jaipur_data['new_car_specs'][i]
    
    data_dict = ast.literal_eval(new_car_detail)
    data_dict_1 = ast.literal_eval(new_car_overview)
    data_dict_2 = ast.literal_eval(new_car_specs)
    
    fuel_type.append(data_dict['ft'])
    Kilometers_driven.append(data_dict['km'])
    Transmission_type.append(data_dict['transmission'])
    No_of_owners.append(data_dict['ownerNo'])
    Original_Equipment_Manufacturer.append(data_dict['oem'])
    model.append(data_dict['model'])
    model_Year.append(int(data_dict['modelYear']))
    Price.append(data_dict['price'])
    registration_year.append(data_dict_1['top'][0]['value'][-4:])
    seats.append(data_dict_1['top'][3]['value'][0])
    
    try:
        if (data_dict_2['data'][0]['list'][2]['value']).isnumeric():
            engine_cc.append(data_dict_2['data'][0]['list'][2]['value'])
        else:
            engine_cc.append(data_dict_2['data'][0]['list'][1]['value'])
    except:
        engine_cc.append(np.nan)
        
    Mileage.append(data_dict_2['top'][0]['value'][:-5])

        
    
jaipur_data['Fuel_Type'] = fuel_type
jaipur_data['Kilometers_Driven'] = Kilometers_driven
jaipur_data['Transmission_Type'] = Transmission_type
jaipur_data['No_of_Owners'] = No_of_owners
jaipur_data['Manufactured_By'] = Original_Equipment_Manufacturer
jaipur_data['Car_Model'] = model
jaipur_data['Car_Produced_Year'] = model_Year
jaipur_data['Car_Price'] = Price
jaipur_data['Registration_Year'] = registration_year
jaipur_data['No_of_Seats'] = seats
jaipur_data['Engine_CC'] = engine_cc
jaipur_data['Mileage(kmpl)'] = Mileage

# %%
jaipur_data
# Out:
#                                          new_car_detail  \
# 0     {'it': 0, 'ft': 'Diesel', 'bt': 'Hatchback', '...
# 1     {'it': 0, 'ft': 'Petrol', 'bt': 'Hatchback', '...
# 2     {'it': 0, 'ft': 'Petrol', 'bt': 'Hatchback', '...
# 3     {'it': 0, 'ft': 'Petrol', 'bt': 'Hatchback', '...
# 4     {'it': 0, 'ft': 'Petrol', 'bt': 'Hatchback', '...
# ...                                                 ...
# 1115  {'it': 0, 'ft': 'Petrol', 'bt': 'Hatchback', '...
# 1116  {'it': 0, 'ft': 'Petrol', 'bt': 'Hatchback', '...
# 1117  {'it': 0, 'ft': 'Petrol', 'bt': 'SUV', 'km': '...
# 1118  {'it': 0, 'ft': 'Petrol', 'bt': 'Hatchback', '...
# 1119  {'it': 0, 'ft': 'Petrol', 'bt': 'Hatchback', '...
#
#                                        new_car_overview  \
# 0     {'heading': 'Car overview', 'top': [{'key': 'R...
# 1     {'heading': 'Car overview', 'top': [{'key': 'R...
# 2     {'heading': 'Car overview', 'top': [{'key': 'R...
# 3     {'heading': 'Car overview', 'top': [{'key': 'R...
# ...

# %%
jaipur_data['Location']='Jaipur'

# %%
kolkata_data=pd.read_excel('C:\\Users\\HP\\Desktop\\capstone.3\\kolkata_cars.xlsx')
fuel_type = []
Kilometers_driven = []
Transmission_type = []
No_of_owners = []
Original_Equipment_Manufacturer = []
model = []
model_Year = []
Price = []
registration_year = []
seats = []
engine_cc = []
Mileage = []

for i in range(kolkata_data.shape[0]):
    new_car_detail = kolkata_data['new_car_detail'][i]
    new_car_overview = kolkata_data['new_car_overview'][i]
    new_car_specs = kolkata_data['new_car_specs'][i]
    
    data_dict = ast.literal_eval(new_car_detail)
    data_dict_1 = ast.literal_eval(new_car_overview)
    data_dict_2 = ast.literal_eval(new_car_specs)
    
    fuel_type.append(data_dict['ft'])
    Kilometers_driven.append(data_dict['km'])
    Transmission_type.append(data_dict['transmission'])
    No_of_owners.append(data_dict['ownerNo'])
    Original_Equipment_Manufacturer.append(data_dict['oem'])
    model.append(data_dict['model'])
    model_Year.append(int(data_dict['modelYear']))
    Price.append(data_dict['price'])
    registration_year.append(data_dict_1['top'][0]['value'][-4:])
    seats.append(data_dict_1['top'][3]['value'][0])
    
    try:
        if (data_dict_2['data'][0]['list'][2]['value']).isnumeric():
            engine_cc.append(data_dict_2['data'][0]['list'][2]['value'])
        else:
            engine_cc.append(data_dict_2['data'][0]['list'][1]['value'])
    except:
        engine_cc.append(np.nan)
        
    Mileage.append(data_dict_2['top'][0]['value'][:-5])

        
    
kolkata_data['Fuel_Type'] = fuel_type
kolkata_data['Kilometers_Driven'] = Kilometers_driven
kolkata_data['Transmission_Type'] = Transmission_type
kolkata_data['No_of_Owners'] = No_of_owners
kolkata_data['Manufactured_By'] = Original_Equipment_Manufacturer
kolkata_data['Car_Model'] = model
kolkata_data['Car_Produced_Year'] = model_Year
kolkata_data['Car_Price'] = Price
kolkata_data['Registration_Year'] = registration_year
kolkata_data['No_of_Seats'] = seats
kolkata_data['Engine_CC'] = engine_cc
kolkata_data['Mileage(kmpl)'] = Mileage

# %%
kolkata_data
# Out:
#                                          new_car_detail  \
# 0     {'it': 0, 'ft': 'Petrol', 'bt': 'Sedan', 'km':...
# 1     {'it': 0, 'ft': 'Petrol', 'bt': 'Hatchback', '...
# 2     {'it': 0, 'ft': 'Petrol', 'bt': 'SUV', 'km': '...
# 3     {'it': 0, 'ft': 'Petrol', 'bt': 'Hatchback', '...
# 4     {'it': 0, 'ft': 'Diesel', 'bt': 'SUV', 'km': '...
# ...                                                 ...
# 1376  {'it': 0, 'ft': 'Petrol', 'bt': 'Hatchback', '...
# 1377  {'it': 0, 'ft': 'Petrol', 'bt': 'Hatchback', '...
# 1378  {'it': 0, 'ft': 'Petrol', 'bt': 'Sedan', 'km':...
# 1379  {'it': 0, 'ft': 'Petrol', 'bt': 'Hatchback', '...
# 1380  {'it': 0, 'ft': 'Diesel', 'bt': 'SUV', 'km': '...
#
#                                        new_car_overview  \
# 0     {'heading': 'Car overview', 'top': [{'key': 'R...
# 1     {'heading': 'Car overview', 'top': [{'key': 'R...
# 2     {'heading': 'Car overview', 'top': [{'key': 'R...
# 3     {'heading': 'Car overview', 'top': [{'key': 'R...
# ...

# %%
kolkata_data['Location']='Kolkata'

# %%
data = pd.concat([bangalore_data,chennai_data,delhi_data,hyderabad_data,jaipur_data,kolkata_data])
data
# Out:
#                                          new_car_detail  \
# 0     {'it': 0, 'ft': 'Petrol', 'bt': 'Hatchback', '...
# 1     {'it': 0, 'ft': 'Petrol', 'bt': 'SUV', 'km': '...
# 2     {'it': 0, 'ft': 'Petrol', 'bt': 'Hatchback', '...
# 3     {'it': 0, 'ft': 'Petrol', 'bt': 'Sedan', 'km':...
# 4     {'it': 0, 'ft': 'Diesel', 'bt': 'SUV', 'km': '...
# ...                                                 ...
# 1376  {'it': 0, 'ft': 'Petrol', 'bt': 'Hatchback', '...
# 1377  {'it': 0, 'ft': 'Petrol', 'bt': 'Hatchback', '...
# 1378  {'it': 0, 'ft': 'Petrol', 'bt': 'Sedan', 'km':...
# 1379  {'it': 0, 'ft': 'Petrol', 'bt': 'Hatchback', '...
# 1380  {'it': 0, 'ft': 'Diesel', 'bt': 'SUV', 'km': '...
#
#                                        new_car_overview  \
# 0     {'heading': 'Car overview', 'top': [{'key': 'R...
# 1     {'heading': 'Car overview', 'top': [{'key': 'R...
# 2     {'heading': 'Car overview', 'top': [{'key': 'R...
# 3     {'heading': 'Car overview', 'top': [{'key': 'R...
# ...

# %%
data.drop(['new_car_detail','new_car_overview','new_car_feature','new_car_specs','car_links'],axis=1,inplace=True)

# %%
data
# Out:
#      Fuel_Type Kilometers_Driven Transmission_Type  No_of_Owners  \
# 0       Petrol          1,20,000            Manual             3
# 1       Petrol            32,706            Manual             2
# 2       Petrol            11,949            Manual             1
# 3       Petrol            17,794            Manual             1
# 4       Diesel            60,000            Manual             1
# ...        ...               ...               ...           ...
# 1376    Petrol            10,000            Manual             1
# 1377    Petrol          1,20,000            Manual             1
# 1378    Petrol            50,000         Automatic             3
# 1379    Petrol            40,000            Manual             1
# 1380    Diesel          1,20,000            Manual             2
#
#      Manufactured_By              Car_Model  Car_Produced_Year    Car_Price  \
# 0             Maruti         Maruti Celerio               2015     ₹ 4 Lakh
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 8369 entries, 0 to 1380
# Data columns (total 13 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Fuel_Type          8369 non-null   object
#  1   Kilometers_Driven  8369 non-null   object
#  2   Transmission_Type  8369 non-null   object
#  3   No_of_Owners       8369 non-null   int64
#  4   Manufactured_By    8369 non-null   object
#  5   Car_Model          8369 non-null   object
#  6   Car_Produced_Year  8369 non-null   int64
#  7   Car_Price          8369 non-null   object
#  8   Registration_Year  8369 non-null   object
#  9   No_of_Seats        8369 non-null   object
#  10  Engine_CC          8312 non-null   object
#  11  Mileage(kmpl)      8369 non-null   object
#  12  Location           8369 non-null   object
# dtypes: int64(2), object(11)
# memory usage: 915.4+ KB

# %%
data[data.duplicated()]
# Out:
#      Fuel_Type Kilometers_Driven Transmission_Type  No_of_Owners  \
# 79      Petrol            60,000            Manual             2
# 114     Petrol            20,000         Automatic             1
# 124     Petrol            80,000            Manual             3
# 183     Petrol          1,20,000            Manual             3
# 197     Petrol            50,000            Manual             1
# ...        ...               ...               ...           ...
# 1224    Petrol            54,000         Automatic             1
# 1276    Petrol            29,000         Automatic             1
# 1309    Petrol            20,000            Manual             1
# 1351    Petrol            10,000            Manual             1
# 1362    Petrol            40,000            Manual             1
#
#      Manufactured_By           Car_Model  Car_Produced_Year     Car_Price  \
# 79            Maruti         Maruti Ritz               2014   ₹ 4.20 Lakh
# ...

# %%
data.drop_duplicates(inplace=True)

# %%
data.shape
# Out:
# (8243, 13)

# %%
data.isnull().sum()
# Out:
# Fuel_Type             0
# Kilometers_Driven     0
# Transmission_Type     0
# No_of_Owners          0
# Manufactured_By       0
# Car_Model             0
# Car_Produced_Year     0
# Car_Price             0
# Registration_Year     0
# No_of_Seats           0
# Engine_CC            57
# Mileage(kmpl)         0
# Location              0
# dtype: int64

# %%
data.Engine_CC
# Out:
# 0        998
# 1       1497
# 2       1199
# 3       1197
# 4       1248
#         ...
# 1376     998
# 1377     796
# 1378    1796
# 1379    1197
# 1380    1461
# Name: Engine_CC, Length: 8243, dtype: object

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 8243 entries, 0 to 1380
# Data columns (total 13 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Fuel_Type          8243 non-null   object
#  1   Kilometers_Driven  8243 non-null   object
#  2   Transmission_Type  8243 non-null   object
#  3   No_of_Owners       8243 non-null   int64
#  4   Manufactured_By    8243 non-null   object
#  5   Car_Model          8243 non-null   object
#  6   Car_Produced_Year  8243 non-null   int64
#  7   Car_Price          8243 non-null   object
#  8   Registration_Year  8243 non-null   object
#  9   No_of_Seats        8243 non-null   object
#  10  Engine_CC          8186 non-null   object
#  11  Mileage(kmpl)      8243 non-null   object
#  12  Location           8243 non-null   object
# dtypes: int64(2), object(11)
# memory usage: 901.6+ KB

# %%
data['Engine_CC'].unique()
# Out:
# array(['998', '1497', '1199', '1197', '1248', '1956', '1198', '1462',
#        '2179', '1950', '1396', '1995', '1498', '4663', '1086', '1991',
#        '1968', '1998', '2982', '1461', '1797', '796', '1353', '2925',
#        '2987', '2967', '999', '1341', '1496', '1582', '1798', '1120',
#        '1969', '1451', '814', '1999', '1591', '1397', '1368', '1598',
#        '3198', '1196', '2993', '2755', '2143', '2354', '1332', '2199',
#        '1997', '1499', '2148', '2696', '1364', '2494', '1373', '1299',
#        '1061', '1493', '2497', '1495', '1590', '1896', '1330', '1781',
#        '1390', '1194', '2953', '1399', '1595', 'Power', '2496',
#        '210AH Lithium Ion', '0', '1984', nan, '2694', '1298', '2362',
#        '2198', '1599', '993', '2393', '1389', '1597', '2498', '2523',
#        '1586', '995', '2499', '2998', '72', '1589', '624', '1596', '799',
#        '3597', '2184', '1405', '5000', '1422', '1047', '2200', '2996',
# ...

# %%
data['Engine_CC'].fillna('meadian',inplace=True)

# %%
data.isnull().sum()
# Out:
# Fuel_Type            0
# Kilometers_Driven    0
# Transmission_Type    0
# No_of_Owners         0
# Manufactured_By      0
# Car_Model            0
# Car_Produced_Year    0
# Car_Price            0
# Registration_Year    0
# No_of_Seats          0
# Engine_CC            0
# Mileage(kmpl)        0
# Location             0
# dtype: int64

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 8243 entries, 0 to 1380
# Data columns (total 13 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Fuel_Type          8243 non-null   object
#  1   Kilometers_Driven  8243 non-null   object
#  2   Transmission_Type  8243 non-null   object
#  3   No_of_Owners       8243 non-null   int64
#  4   Manufactured_By    8243 non-null   object
#  5   Car_Model          8243 non-null   object
#  6   Car_Produced_Year  8243 non-null   int64
#  7   Car_Price          8243 non-null   object
#  8   Registration_Year  8243 non-null   object
#  9   No_of_Seats        8243 non-null   object
#  10  Engine_CC          8243 non-null   object
#  11  Mileage(kmpl)      8243 non-null   object
#  12  Location           8243 non-null   object
# dtypes: int64(2), object(11)
# memory usage: 901.6+ KB

# %%
print(data.columns)
# Out:
# Index(['Fuel_Type', 'Kilometers_Driven', 'Transmission_Type', 'No_of_Owners',
#        'Manufactured_By', 'Car_Model', 'Car_Produced_Year', 'Car_Price',
#        'Registration_Year', 'No_of_Seats', 'Engine_CC', 'Mileage(kmpl)',
#        'Location'],
#       dtype='object')

# %%
data['Kilometers_Driven']=data['Kilometers_Driven'].astype(str).str.replace(',','').astype('int')
data['Registration_Year']=pd.to_numeric(data['Registration_Year'].astype(str),errors='coerce').fillna(0).astype('int')
data['No_of_Seats'] =pd.to_numeric(data['No_of_Seats'].astype(str),errors='coerce').fillna(0).astype('int')
data['Engine_CC'] =pd.to_numeric(data['Engine_CC'].astype(str),errors='coerce').fillna(0).astype('int')
data['Mileage(kmpl)'] =pd.to_numeric(data['Mileage(kmpl)'].astype(str),errors='coerce').fillna(0).astype('float')

# %%
# First, remove the currency symbol '₹' and strip whitespace
data['Car_Price'] = data['Car_Price'].str.replace('₹', '').str.strip()

# Then, handle 'Lakh' by converting to numeric value
data['Car_Price'] = data['Car_Price'].str.replace('Lakh', '').str.strip()

# Now, convert to float, while coercing errors to NaN
data['Car_Price'] = pd.to_numeric(data['Car_Price'], errors='coerce')

# %%
data['Car_Price'] = data['Car_Price'].astype(float)*100000

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 8243 entries, 0 to 1380
# Data columns (total 13 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Fuel_Type          8243 non-null   object
#  1   Kilometers_Driven  8243 non-null   int64
#  2   Transmission_Type  8243 non-null   object
#  3   No_of_Owners       8243 non-null   int64
#  4   Manufactured_By    8243 non-null   object
#  5   Car_Model          8243 non-null   object
#  6   Car_Produced_Year  8243 non-null   int64
#  7   Car_Price          8115 non-null   float64
#  8   Registration_Year  8243 non-null   int64
#  9   No_of_Seats        8243 non-null   int64
#  10  Engine_CC          8243 non-null   int64
#  11  Mileage(kmpl)      8243 non-null   float64
#  12  Location           8243 non-null   object
# dtypes: float64(2), int64(6), object(5)
# memory usage: 901.6+ KB

# %%
data
# Out:
#      Fuel_Type  Kilometers_Driven Transmission_Type  No_of_Owners  \
# 0       Petrol             120000            Manual             3
# 1       Petrol              32706            Manual             2
# 2       Petrol              11949            Manual             1
# 3       Petrol              17794            Manual             1
# 4       Diesel              60000            Manual             1
# ...        ...                ...               ...           ...
# 1376    Petrol              10000            Manual             1
# 1377    Petrol             120000            Manual             1
# 1378    Petrol              50000         Automatic             3
# 1379    Petrol              40000            Manual             1
# 1380    Diesel             120000            Manual             2
#
#      Manufactured_By              Car_Model  Car_Produced_Year  Car_Price  \
# 0             Maruti         Maruti Celerio               2015   400000.0
# ...

# %%
data.isnull().sum()
# Out:
# Fuel_Type              0
# Kilometers_Driven      0
# Transmission_Type      0
# No_of_Owners           0
# Manufactured_By        0
# Car_Model              0
# Car_Produced_Year      0
# Car_Price            128
# Registration_Year      0
# No_of_Seats            0
# Engine_CC              0
# Mileage(kmpl)          0
# Location               0
# dtype: int64

# %%
data.dropna(inplace=True)

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 8115 entries, 0 to 1380
# Data columns (total 13 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Fuel_Type          8115 non-null   object
#  1   Kilometers_Driven  8115 non-null   int64
#  2   Transmission_Type  8115 non-null   object
#  3   No_of_Owners       8115 non-null   int64
#  4   Manufactured_By    8115 non-null   object
#  5   Car_Model          8115 non-null   object
#  6   Car_Produced_Year  8115 non-null   int64
#  7   Car_Price          8115 non-null   float64
#  8   Registration_Year  8115 non-null   int64
#  9   No_of_Seats        8115 non-null   int64
#  10  Engine_CC          8115 non-null   int64
#  11  Mileage(kmpl)      8115 non-null   float64
#  12  Location           8115 non-null   object
# dtypes: float64(2), int64(6), object(5)
# memory usage: 887.6+ KB

# %%
data.to_csv('overalldata.csv',index=False)

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
print(data.describe())
# Out:
#        Kilometers_Driven  No_of_Owners  Car_Produced_Year     Car_Price  \
# count       8.115000e+03   8115.000000        8115.000000  8.115000e+03
# mean        5.874575e+04      1.347874        2016.646334  9.281368e+05
# std         7.486818e+04      0.625731           3.716026  1.062805e+06
# min         0.000000e+00      0.000000        1985.000000  1.000000e+05
# 25%         3.000000e+04      1.000000        2014.000000  4.000000e+05
# 50%         5.333800e+04      1.000000        2017.000000  6.110000e+05
# 75%         8.000000e+04      2.000000        2019.000000  9.500000e+05
# max         5.500000e+06      5.000000        2023.000000  9.600000e+06
#
#        Registration_Year  No_of_Seats    Engine_CC  Mileage(kmpl)
# count        8115.000000  8115.000000  8115.000000    8115.000000
# mean         2006.794578     5.195810  1416.414911      19.163223
# std           141.296826     0.691319   479.157590       4.217178
# ...

# %%
# Visualize missing values (if any)
sns.heatmap(data.isnull(), cbar=False, cmap="viridis")
plt.title("Missing Values Heatmap")
plt.show()

# %%
numeric_columns = ['Car_Price', 'Kilometers_Driven', 'Engine_CC', 'Mileage(kmpl)']
# Plot histograms for each numeric feature
data[numeric_columns].hist(bins=20, figsize=(10, 10), color='skyblue', edgecolor='black')
plt.suptitle('Histograms of Numeric Features')
plt.show()

# %%
categorical_columns = ['Fuel_Type', 'Transmission_Type', 'Manufactured_By', 'Car_Model', 'Location']

for col in categorical_columns:
    plt.figure(figsize=(10, 5))
    sns.countplot(data[col], order=data[col].value_counts().index, palette="Set2")
    plt.title(f"Distribution of {col}")
    plt.xticks(rotation=45)
    plt.show()
# Out:
# C:\Users\HP\AppData\Local\Temp\ipykernel_24228\1309454636.py:5: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(data[col], order=data[col].value_counts().index, palette="Set2")
# C:\Users\HP\AppData\Local\Temp\ipykernel_24228\1309454636.py:5: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(data[col], order=data[col].value_counts().index, palette="Set2")
# C:\Users\HP\AppData\Local\Temp\ipykernel_24228\1309454636.py:5: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
# ...

# %%
# Scatter plot for numeric features against Car_Price
for col in numeric_columns:
    if col != 'Car_Price':
        plt.figure(figsize=(6, 4))
        sns.scatterplot(x=data[col], y=data['Car_Price'], alpha=0.6, color='purple')
        plt.title(f"{col} vs Car_Price")
        plt.xlabel(col)
        plt.ylabel('Car_Price')
        plt.show()

# %%
# Box plots for categorical features against Car_Price
for col in categorical_columns:
    plt.figure(figsize=(10, 5))
    sns.boxplot(x=data[col], y=data['Car_Price'], palette="Pastel1")
    plt.title(f"{col} vs Car_Price")
    plt.xticks(rotation=45)
    plt.show()
# Out:
# C:\Users\HP\AppData\Local\Temp\ipykernel_24228\3068744878.py:4: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(x=data[col], y=data['Car_Price'], palette="Pastel1")
# C:\Users\HP\AppData\Local\Temp\ipykernel_24228\3068744878.py:4: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(x=data[col], y=data['Car_Price'], palette="Pastel1")
# C:\Users\HP\AppData\Local\Temp\ipykernel_24228\3068744878.py:4: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(x=data[col], y=data['Car_Price'], palette="Pastel1")
# ...

# %%
# Boxplots for outlier detection
for col in numeric_columns:
    plt.figure(figsize=(6, 4))
    sns.boxplot(data[col], color='coral')
    plt.title(f"Boxplot of {col}")
    plt.show()

# %%
import matplotlib.pyplot as plt
import seaborn as sns
plt.figure(figsize=(30,20))
sns.boxplot(data=data)
plt.show()

# %%
for i in data.columns:
    plt.figure(figsize=(20,8))
    sns.boxplot(data=data[i])
    plt.show()

# %%
data.Fuel_Type.unique()
# Out:
# array(['Petrol', 'Diesel', 'Lpg', 'Cng', 'Electric'], dtype=object)

# %%
data.Transmission_Type.unique()
# Out:
# array(['Manual', 'Automatic'], dtype=object)

# %%
data.Manufactured_By.unique()
# Out:
# array(['Maruti', 'Ford', 'Tata', 'Hyundai', 'Jeep', 'Datsun', 'Honda',
#        'Mahindra', 'Mercedes-Benz', 'BMW', 'Renault', 'Audi', 'Toyota',
#        'Mini', 'Kia', 'Skoda', 'Volkswagen', 'Volvo', 'MG', 'Nissan',
#        'Fiat', 'Mahindra Ssangyong', 'Mitsubishi', 'Jaguar', 'Land Rover',
#        'Chevrolet', 'Citroen', 'Opel', 'Mahindra Renault', 'Isuzu',
#        'Lexus', 'Porsche', 'Hindustan Motors'], dtype=object)

# %%
data.Car_Model.unique()
# Out:
# array(['Maruti Celerio', 'Ford Ecosport', 'Tata Tiago', 'Hyundai Xcent',
#        'Maruti SX4 S Cross', 'Jeep Compass', 'Datsun GO', 'Hyundai Venue',
#        'Maruti Ciaz', 'Maruti Baleno', 'Hyundai Grand i10', 'Honda Jazz',
#        'Mahindra XUV500', 'Mercedes-Benz GLA', 'Hyundai i20',
#        'Tata Nexon', 'Honda City', 'BMW 5 Series', 'Maruti Swift',
#        'Renault Duster', 'Mercedes-Benz S-Class', 'Hyundai Santro',
#        'Hyundai Santro Xing', 'Mercedes-Benz E-Class', 'Audi A4',
#        'Maruti Wagon R', 'Maruti Ertiga', 'Mercedes-Benz C-Class',
#        'Toyota Fortuner', 'Hyundai Elantra', 'Audi A6', 'Maruti Alto 800',
#        'Mahindra Scorpio', 'Mini 3 DOOR', 'Kia Seltos', 'Maruti Alto',
#        'Mercedes-Benz GL-Class', 'Tata New Safari', 'Audi Q7',
#        'Renault KWID', 'Hyundai Getz', 'Skoda Rapid', 'Hyundai Creta',
#        'Tata Harrier', 'BMW 3 Series GT', 'Renault Lodgy',
#        'Skoda Octavia', 'Maruti Ritz', 'Volkswagen Polo',
# ...

# %%
from sklearn.preprocessing import LabelEncoder
from sklearn.preprocessing import OneHotEncoder
from sklearn.preprocessing import OrdinalEncoder
from sklearn.preprocessing import TargetEncoder

ordinal=OrdinalEncoder()
label=LabelEncoder()
ohe=OneHotEncoder()
target=TargetEncoder()
data['Fuel_Type'] = label.fit_transform(data['Fuel_Type'])
data['Transmission_Type']=ordinal.fit_transform(data['Transmission_Type'].values.reshape(-1,1))
data['Location']=label.fit_transform(data['Location'])
data['Manufactured_By']=label.fit_transform(data['Manufactured_By'])
data['Car_Model']=label.fit_transform(data['Car_Model'])

# %%
data
# Out:
#       Fuel_Type  Kilometers_Driven  Transmission_Type  No_of_Owners  \
# 0             4             120000                1.0             3
# 1             4              32706                1.0             2
# 2             4              11949                1.0             1
# 3             4              17794                1.0             1
# 4             1              60000                1.0             1
# ...         ...                ...                ...           ...
# 1376          4              10000                1.0             1
# 1377          4             120000                1.0             1
# 1378          4              50000                0.0             3
# 1379          4              40000                1.0             1
# 1380          1             120000                1.0             2
#
#       Manufactured_By  Car_Model  Car_Produced_Year  Car_Price  \
# 0                  20        152               2015   400000.0
# ...

# %%
data.corr()
# Out:
#                    Fuel_Type  Kilometers_Driven  Transmission_Type  \
# Fuel_Type           1.000000          -0.175825           0.076523
# Kilometers_Driven  -0.175825           1.000000           0.049969
# Transmission_Type   0.076523           0.049969           1.000000
# No_of_Owners       -0.068986           0.101354           0.032020
# Manufactured_By    -0.025672           0.018831           0.052489
# Car_Model          -0.046693           0.027357           0.041169
# Car_Produced_Year   0.111950          -0.223849          -0.172153
# Car_Price          -0.262876          -0.051760          -0.481805
# Registration_Year  -0.017335          -0.002424          -0.029191
# No_of_Seats        -0.270653           0.071205           0.019308
# Engine_CC          -0.499585           0.108394          -0.297918
# Mileage(kmpl)      -0.075758          -0.003765           0.220106
# Location           -0.011720          -0.034565           0.095824
#
# ...

# %%
plt.figure(figsize=(10,8))
sns.heatmap(data.corr(),annot=True,vmin=-1,vmax=1)
plt.show()

# %%
data.to_csv('preprocessing',index=False)

# %%
#ml
df=pd.read_csv('preprocessing')
df
# Out:
#       Fuel_Type  Kilometers_Driven  Transmission_Type  No_of_Owners  \
# 0             4             120000                1.0             3
# 1             4              32706                1.0             2
# 2             4              11949                1.0             1
# 3             4              17794                1.0             1
# 4             1              60000                1.0             1
# ...         ...                ...                ...           ...
# 6666          4              10000                1.0             1
# 6667          4             120000                1.0             1
# 6668          4              50000                0.0             3
# 6669          4              40000                1.0             1
# 6670          1             120000                1.0             2
#
#       Manufactured_By  Car_Model  Car_Produced_Year  Car_Price  \
# 0                  20        152               2015   400000.0
# ...

# %%
from sklearn.linear_model import LinearRegression
feature=df.drop(['Car_Price'],axis=1)
target=df['Car_Price']

# %%
feature.values
# Out:
# array([[4.0000e+00, 1.2000e+05, 1.0000e+00, ..., 9.9800e+02, 2.3100e+01,
#         0.0000e+00],
#        [4.0000e+00, 3.2706e+04, 1.0000e+00, ..., 1.4970e+03, 1.7000e+01,
#         0.0000e+00],
#        [4.0000e+00, 1.1949e+04, 1.0000e+00, ..., 1.1990e+03, 2.3840e+01,
#         0.0000e+00],
#        ...,
#        [4.0000e+00, 5.0000e+04, 0.0000e+00, ..., 1.7960e+03, 1.1740e+01,
#         4.0000e+00],
#        [4.0000e+00, 4.0000e+04, 1.0000e+00, ..., 1.1970e+03, 1.8500e+01,
#         4.0000e+00],
#        [1.0000e+00, 1.2000e+05, 1.0000e+00, ..., 1.4610e+03, 1.9720e+01,
#         4.0000e+00]])

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(feature,target,test_size=0.2,random_state=39)

# %%
#linear regression model
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error,mean_absolute_error,r2_score
x_train,x_test,y_train,y_test=train_test_split(feature,target,test_size=0.2,random_state=39)
linear_model = LinearRegression()
linear_model.fit(x_train,y_train)
y_pred_test = linear_model.predict(x_test)
y_pred_train=linear_model.predict(x_train)

print(mean_absolute_error(y_train, y_pred_train))
print(mean_absolute_error(y_test, y_pred_test))
print(r2_score(y_train, y_pred_train))
print(r2_score(y_test, y_pred_test))
# Out:
# 353017.2696918483
# 341314.476782517
# 0.5326216792201295
# 0.6088344039996592

# %%
#ridge regression model
from sklearn.linear_model import LinearRegression,Ridge,Lasso
x_train,x_test,y_train,y_test=train_test_split(feature,target,test_size=0.2,random_state=39)
ridge_model = Ridge(alpha=0.2)
ridge_model.fit(x_train,y_train)

y_pred_test=ridge_model.predict(x_test)
y_pred_train=ridge_model.predict(x_train)

print(mean_absolute_error(y_train, y_pred_train))
print(mean_absolute_error(y_test, y_pred_test))
print(r2_score(y_train, y_pred_train))
print(r2_score(y_test, y_pred_test))
# Out:
# 353012.1343984107
# 341310.7728198354
# 0.5326216764164686
# 0.6088357137922888

# %%
#lasso regression
x_train,x_test,y_train,y_test=train_test_split(feature,target,test_size=0.2,random_state=39)
lasso_model = Lasso(alpha=0.2)
lasso_model.fit(x_train,y_train)
y_pred_test = lasso_model.predict(x_test)
y_pred_train=lasso_model.predict(x_train)

print(mean_absolute_error(y_train, y_pred_train))
print(mean_absolute_error(y_test, y_pred_test))
print(r2_score(y_train, y_pred_train))
print(r2_score(y_test, y_pred_test))
# Out:
# 353017.1673607526
# 341314.4151041869
# 0.5326216792195562
# 0.6088343777948557
# c:\Users\HP\Desktop\capstone.3\env\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:697: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 2.478e+12, tolerance: 4.598e+11
#   model = cd_fast.enet_coordinate_descent(

# %%
#knn regressor model
from sklearn.neighbors import KNeighborsRegressor
x_train,x_test,y_train,y_test=train_test_split(feature,target,test_size=0.2,random_state=39)
knn_model=KNeighborsRegressor(n_neighbors=4,weights='distance')
knn_model.fit(x_train,y_train)
y_pred_test=knn_model.predict(x_test)
y_pred_train=knn_model.predict(x_train)

print(mean_absolute_error(y_train, y_pred_train))
print(mean_absolute_error(y_test, y_pred_test))
print(r2_score(y_train, y_pred_train))
print(r2_score(y_test, y_pred_test))
# Out:
# 955.5847076461769
# 337672.70204938314
# 0.9997600845882775
# 0.4859783397543781

# %%
#Decision tree rRegressor model
from sklearn.tree import DecisionTreeRegressor
model_DT = DecisionTreeRegressor(criterion = 'squared_error', max_depth =12, min_samples_split =10, min_samples_leaf =3, random_state=2)
model_DT.fit(x_train,y_train)
from sklearn.metrics import mean_squared_error,mean_absolute_error,mean_absolute_percentage_error,r2_score

y_pred_test = model_DT.predict(x_test)
y_pred_train = model_DT.predict(x_train)

print(mean_absolute_error(y_train, y_pred_train))
print(mean_absolute_error(y_test, y_pred_test))
print(r2_score(y_train, y_pred_train))
print(r2_score(y_test, y_pred_test))
# Out:
# 105464.9156706469
# 161822.37823202956
# 0.938942265411656
# 0.8460805773061914

# %%
#RandomForestRegressor model
from sklearn.ensemble import RandomForestRegressor
model_RF = RandomForestRegressor(criterion = 'squared_error',n_estimators=200,max_depth =15, min_samples_split =7, min_samples_leaf =5, random_state=2)
model_RF.fit(x_train,y_train)

y_pred_test = model_RF.predict(x_test)
y_pred_train = model_RF.predict(x_train)

print(mean_absolute_error(y_train, y_pred_train))
print(mean_absolute_error(y_test, y_pred_test))
print(r2_score(y_train, y_pred_train))
print(r2_score(y_test, y_pred_test))
# Out:
# 107505.03030858896
# 139189.36202039727
# 0.9267351851378249
# 0.882377127064082

# %%
#AdaboosterRegressor model
from sklearn.ensemble import AdaBoostRegressor
model_ada = AdaBoostRegressor(n_estimators=300, learning_rate=0.001)
model_ada.fit(x_train,y_train)

y_pred_test = model_ada.predict(x_test)
y_pred_train = model_ada.predict(x_train)

print(mean_absolute_error(y_train, y_pred_train))
print(mean_absolute_error(y_test, y_pred_test))
print(r2_score(y_train, y_pred_train))
print(r2_score(y_test, y_pred_test))
# Out:
# 271998.381766619
# 270078.4973336219
# 0.6785542667825192
# 0.6911654300362284

# %%
#GradientBoostingRegressor model
from sklearn.ensemble import GradientBoostingRegressor
model_GB = GradientBoostingRegressor(n_estimators=400, max_depth=10, min_samples_split=4, learning_rate=0.01)
model_GB.fit(x_train,y_train)
y_pred_test = model_GB.predict(x_test)
y_pred_train = model_GB.predict(x_train)

print(mean_absolute_error(y_train, y_pred_train))
print(mean_absolute_error(y_test, y_pred_test))
print(r2_score(y_train, y_pred_train))
print(r2_score(y_test, y_pred_test))
# Out:
# 40357.59302865294
# 125792.87210399279
# 0.9953330759037008
# 0.895105406717856

# %%
import pickle

with open('GradientBoost_model.pkl', 'wb') as file:
    pickle.dump(model_GB,file)

# %%
import pickle

with open('RandomForest_model.pkl', 'wb') as file:
    pickle.dump(model_RF,file)
